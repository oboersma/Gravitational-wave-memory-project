# %%
import gwsurrogate as gws

# %%
# %matplotlib notebook

# %%
import matplotlib

# %%
import numpy as np

# %%
import deriv1d
from matplotlib import pyplot as plt
from scipy.interpolate import interp1d
from scipy import integrate
c_SI = 299792458
PC_SI = 3.0857e16
#Sol_SI = 
M = 65
q = 36.0/29.0
theta = (140.0/180.0)*np.pi
phi = 0
psi = 1.8
dist = 410
distance = dist*1.e6*PC_SI
ell_m = [(2,0),(2,1),(2,2),(3,1),(3,2),(3,3)]
spec = gws.EvaluateSurrogate('SpEC_q1_10_NoSpin_nu5thDegPoly_exclude_2_0.h5',ell_m=ell_m,excluded=None)
# Out:
# ...
# loading surrogate mode... l2_m0
# loading surrogate mode... l2_m1
# loading surrogate mode... l2_m2
# loading surrogate mode... l3_m1
# loading surrogate mode... l3_m2
# loading surrogate mode... l3_m3

# %%
ell = [2,2,3,3,3]
m = [1,2,1,2,3]
#fp = -0.1804
#fc = 0.4282
fp = -0.44
fc =0.27
fp1 = -fp
fc1 = -fc
Ns = 4096
deltaT = 1/4096.
ts = np.arange(-0.8,0.2,deltaT)
total = np.zeros(len(ts))
total22 = np.zeros(len(ts))

# %%
times22,hpmem,hcmem = spec.evaluate_single_mode(q=q, M=M,dist=dist,f_low=None,samples=ts,samples_units='mks',ell=2,m=2)
times20,hp0,hc0 = spec.evaluate_single_mode(q=q,M=M,dist=dist,f_low=None,samples=ts,samples_units='mks',ell=2,m=0)
plt.plot(times22,hpmem*fp+hcmem*fc)
# Out:
# <img src="data:image/png;base64,...">

# %%
ylim([-1.5e-21,1.5e-21])
# Out:
# (-1.5e-21, 1.5e-21)

# %%
from pylab import *
